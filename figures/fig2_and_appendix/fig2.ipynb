# %%
import svgutils.transform as sg
import sys 


#create new SVG figure
fig = sg.SVGFigure(width="15.cm", height="9.5cm")

fig1 = sg.fromfile("simple_gaussian.svg")
fig2 = sg.fromfile("bm_10k_c2st.svg")
fig3 = sg.fromfile("bm_100k_c2st.svg")
# fig2 = sg.fromfile("lotka_volterra_metrics.svg")
# fig3 = sg.fromfile("sir_fig.svg")
fig4 = sg.fromfile("samplers.svg")
fig5 = sg.fromfile("proposal_c2st.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()
plot3 = fig3.getroot()
plot4 = fig4.getroot()
plot5 = fig5.getroot()

plot1.moveto(-2, 5)
plot2.moveto(0,150)
plot3.moveto(0,240)
plot4.moveto(400, 0)
plot5.moveto(400, 145)
# plot2_2.moveto(110, 95)
# plot3.moveto(110, 145)
# plot3_2.moveto(110, 185)


txt1 = sg.TextElement(0,10, "a", size=11, weight="bold", font="Arial")
txt2 = sg.TextElement(410,10, "b", size=11, weight="bold", font="Arial")
txt3 = sg.TextElement(0,160, "c", size=11, weight="bold", font="Arial")
txt4 = sg.TextElement(410,160, "d", size=11, weight="bold", font="Arial")

fig.append([plot1, plot2, plot3, plot4, plot5])
fig.append([txt1, txt2, txt3, txt4])

fig.save("fig2_c2st.svg")
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
from IPython.display import SVG

SVG(fig.to_str())

# %%
import svgutils.transform as sg
import sys 


#create new SVG figure
fig = sg.SVGFigure(width="15.cm", height="9.5cm")

fig1 = sg.fromfile("simple_gaussian_swd.svg")
fig2 = sg.fromfile("bm_10k.svg")
fig3 = sg.fromfile("bm_100k.svg")
# fig2 = sg.fromfile("lotka_volterra_metrics.svg")
# fig3 = sg.fromfile("sir_fig.svg")
fig4 = sg.fromfile("samplers_swd.svg")
fig5 = sg.fromfile("proposal.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()
plot3 = fig3.getroot()
plot4 = fig4.getroot()
plot5 = fig5.getroot()

plot1.moveto(0, 5)
plot2.moveto(0,150)
plot3.moveto(0,240)
plot4.moveto(400, 0)
plot5.moveto(400, 162)
# plot2_2.moveto(110, 95)
# plot3.moveto(110, 145)
# plot3_2.moveto(110, 185)


txt1 = sg.TextElement(0,10, "a", size=11, weight="bold", font="Arial")
txt2 = sg.TextElement(410,10, "b", size=11, weight="bold", font="Arial")
txt3 = sg.TextElement(0,160, "c", size=11, weight="bold", font="Arial")
txt4 = sg.TextElement(410,160, "d", size=11, weight="bold", font="Arial")

fig.append([plot1, plot2, plot3, plot4, plot5])
fig.append([txt1, txt2, txt3, txt4])

fig.save("fig2_swd.svg")

# %%
from IPython.display import SVG

SVG(fig.to_str())

# %% [markdown]
# ## Appendix

# %%
fig = sg.SVGFigure(width="15.cm", height="6cm")

fig1 = sg.fromfile("samplers_swd_full_em.svg")
fig2 = sg.fromfile("samplers_swd_full_pc.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()

plot1.moveto(0, 0)
plot2.moveto(0,100)

fig.append([plot1, plot2])

fig.save("appendix_sampler_results.svg")

# %%
from IPython.display import SVG

SVG(fig.to_str())

# %%
fig = sg.SVGFigure(width="14.cm", height="6cm")

fig1 = sg.fromfile("samplers_swd_full_em100.svg")
fig2 = sg.fromfile("samplers_swd_full_pc100.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()

plot1.moveto(0, 0)
plot2.moveto(0,100)

fig.append([plot1, plot2])

fig.save("appendix_sampler_results100.svg")

# %%
fig = sg.SVGFigure(width="14.cm", height="12cm")

fig1 = sg.fromfile("appendix_sampler_results.svg")
fig2 = sg.fromfile("appendix_sampler_results100.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()

plot1.moveto(0, 0)
plot2.moveto(0,210)

txt1 = sg.TextElement(0,10, "a", size=11, weight="bold", font="Arial")
txt2 = sg.TextElement(0,220, "b", size=11, weight="bold", font="Arial")

fig.append([plot1, plot2,txt1,txt2])

fig.save("appendix_fig_sampler.svg")

# %%
from IPython.display import SVG

SVG(fig.to_str())

# %%
fig = sg.SVGFigure(width="15.cm", height="6cm")

fig1 = sg.fromfile("samplers_swd_full_em_c2st.svg")
fig2 = sg.fromfile("samplers_swd_full_pc_c2st.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()

plot1.moveto(0, 0)
plot2.moveto(0,100)

fig.append([plot1, plot2])

fig.save("appendix_sampler_results_c2st.svg")

# %%
fig = sg.SVGFigure(width="14.cm", height="6cm")

fig1 = sg.fromfile("samplers_swd_full_em_c2st100.svg")
fig2 = sg.fromfile("samplers_swd_full_pc_c2st100.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()

plot1.moveto(0, 0)
plot2.moveto(0,100)

fig.append([plot1, plot2])

fig.save("appendix_sampler_results_c2st100.svg")

# %%
fig = sg.SVGFigure(width="14.cm", height="12cm")

fig1 = sg.fromfile("appendix_sampler_results_c2st.svg")
fig2 = sg.fromfile("appendix_sampler_results_c2st100.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()

plot1.moveto(0, 0)
plot2.moveto(0,210)

txt1 = sg.TextElement(0,10, "a", size=11, weight="bold", font="Arial")
txt2 = sg.TextElement(0,220, "b", size=11, weight="bold", font="Arial")

fig.append([plot1, plot2,txt1,txt2])

fig.save("appendix_fig_sampler_c2st.svg")

# %%
from IPython.display import SVG

SVG(fig.to_str())

# %%
fig = sg.SVGFigure(width="14.cm", height="12cm")

fig1 = sg.fromfile("bm5_10k_c2st.svg")
fig2 = sg.fromfile("bm5_100k_c2st.svg")
fig3= sg.fromfile("bm5_10k.svg")
fig4 = sg.fromfile("bm5_100k.svg")


plot1 = fig1.getroot()
plot2 = fig2.getroot()
plot3 = fig3.getroot()
plot4 = fig4.getroot()

plot1.moveto(0, 0)
plot2.moveto(0,90)
plot3.moveto(0,200)
plot4.moveto(0,290)

txt1 = sg.TextElement(0,10, "a", size=11, weight="bold", font="Arial")
txt2 = sg.TextElement(0,200, "b", size=11, weight="bold", font="Arial")

fig.append([plot1, plot2, plot3, plot4, txt1,txt2])

fig.save("appendix_fig_bm5.svg")

# %%
from IPython.display import SVG

SVG(fig.to_str())
